# %%
import os

import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# requirement
root_folder = os.path.abspath('../../data')
print(f'root: {root_folder}')

training_data = datasets.FashionMNIST(
    root=root_folder,
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root=root_folder,
    train=False,
    download=True,
    transform=ToTensor()
)

train_dataloader = DataLoader(training_data, batch_size=32)
test_dataloader = DataLoader(test_data, batch_size=32)

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()
# Out:
# root: F:\XudongDuan\workspace\Common\AIFramework\data

# %%
# hypre-parameter
epochs = 5
lr = 0.001
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def train(data_loader, model, loss_fn, optimizer):
    size = len(data_loader.dataset)
    
    model.train()
    for batch, (x, y) in enumerate(data_loader):
        pred = model(x)
        loss = loss_fn(pred, y)
        
        # optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if batch % 100 == 0:
            print(f"loss: {loss.item():>7f}  batch: {batch}")

# %%
def test(data_loader, model, loss_fn):
    size = len(data_loader.dataset)
    num_batches = len(data_loader)
    test_loss, correct = 0, 0
    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.270850  batch: 0
# loss: 1.273455  batch: 100
# loss: 1.262698  batch: 200
# loss: 1.301399  batch: 300
# loss: 1.166425  batch: 400
# loss: 1.326910  batch: 500
# loss: 1.046926  batch: 600
# loss: 1.069811  batch: 700
# loss: 1.141447  batch: 800
# loss: 1.182249  batch: 900
# loss: 1.024382  batch: 1000
# loss: 0.959052  batch: 1100
# loss: 1.237900  batch: 1200
# loss: 1.073929  batch: 1300
# loss: 1.017938  batch: 1400
# loss: 0.930654  batch: 1500
# loss: 1.070046  batch: 1600
# loss: 1.151174  batch: 1700
# loss: 0.917709  batch: 1800
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.998111
#
# Epoch 2
# -------------------------------
# loss: 0.959306  batch: 0
# loss: 0.995089  batch: 100
# loss: 0.993944  batch: 200
# loss: 1.115300  batch: 300
# loss: 0.902234  batch: 400
# loss: 1.112877  batch: 500
# loss: 0.803475  batch: 600
# loss: 0.815110  batch: 700
# loss: 0.914104  batch: 800
# loss: 1.062389  batch: 900
# loss: 0.841101  batch: 1000
# loss: 0.778304  batch: 1100
# loss: 1.101779  batch: 1200
# loss: 0.939893  batch: 1300
# loss: 0.884742  batch: 1400
# loss: 0.760600  batch: 1500
# loss: 0.907103  batch: 1600
# loss: 1.034972  batch: 1700
# loss: 0.784362  batch: 1800
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.865248
#
# Epoch 3
# -------------------------------
# loss: 0.799265  batch: 0
# loss: 0.882528  batch: 100
# loss: 0.854037  batch: 200
# loss: 0.993221  batch: 300
# loss: 0.766121  batch: 400
# loss: 1.006226  batch: 500
# loss: 0.679049  batch: 600
# loss: 0.672661  batch: 700
# loss: 0.794042  batch: 800
# loss: 1.005706  batch: 900
# loss: 0.743435  batch: 1000
# loss: 0.684237  batch: 1100
# loss: 1.021353  batch: 1200
# loss: 0.882508  batch: 1300
# loss: 0.827051  batch: 1400
# loss: 0.673306  batch: 1500
# loss: 0.816570  batch: 1600
# loss: 0.957917  batch: 1700
# loss: 0.718093  batch: 1800
# Test Error:
#  Accuracy: 70.8%, Avg loss: 0.789358
#
# Epoch 4
# -------------------------------
# loss: 0.703795  batch: 0
# loss: 0.831496  batch: 100
# loss: 0.760892  batch: 200
# loss: 0.893922  batch: 300
# loss: 0.684998  batch: 400
# loss: 0.947652  batch: 500
# loss: 0.608849  batch: 600
# loss: 0.581439  batch: 700
# loss: 0.717122  batch: 800
# loss: 0.964890  batch: 900
# loss: 0.691059  batch: 1000
# loss: 0.629672  batch: 1100
# loss: 0.957868  batch: 1200
# loss: 0.856362  batch: 1300
# loss: 0.796760  batch: 1400
# loss: 0.621003  batch: 1500
# loss: 0.756092  batch: 1600
# loss: 0.899339  batch: 1700
# loss: 0.679800  batch: 1800
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.738326
#
# Epoch 5
# -------------------------------
# loss: 0.637975  batch: 0
# loss: 0.801355  batch: 100
# loss: 0.690817  batch: 200
# loss: 0.813764  batch: 300
# loss: 0.628258  batch: 400
# loss: 0.908675  batch: 500
# loss: 0.565196  batch: 600
# loss: 0.515599  batch: 700
# loss: 0.662260  batch: 800
# loss: 0.928849  batch: 900
# loss: 0.662062  batch: 1000
# loss: 0.593036  batch: 1100
# loss: 0.901508  batch: 1200
# loss: 0.841713  batch: 1300
# loss: 0.774676  batch: 1400
# loss: 0.584484  batch: 1500
# loss: 0.710526  batch: 1600
# loss: 0.852010  batch: 1700
# loss: 0.654642  batch: 1800
# Test Error:
#  Accuracy: 75.1%, Avg loss: 0.699240
#
# Done!

# %%
# scheduler
print(f'initial optimizer: {optimizer}')
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
for i in range(10):
    scheduler.step()
    print(f'optimizer in epoch {i} : {optimizer}')
# Out:
# initial optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.0003486784401
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 0 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00031381059609000004
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 1 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00028242953648100003
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 2 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00025418658283290005
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 3 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00022876792454961005
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 4 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00020589113209464906
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 5 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00018530201888518417
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 6 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00016677181699666576
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 7 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.0001500946352969992
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 8 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.0001350851717672993
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# optimizer in epoch 9 : SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     initial_lr: 0.001
#     lr: 0.00012157665459056936
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
